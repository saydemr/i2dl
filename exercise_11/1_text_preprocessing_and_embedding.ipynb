# %% [markdown]
# # Text Processing and Word Embeddings
#
# Welcome to this new exercise! In this exercise, we will play around with text instead of images as before, using Recurrent Neural Networks. Generally, it is called Natural Language Processing (NLP) when dealing with text, speech, etc. But the data structure is very different from images, i.e., text is a string, while images consist of numbers. Hence, we need some preprocessing steps to transform the raw text into another data format. This notebook will introduce these basic concepts in NLP pipelines. Specifically, you will learn about:
#
# 1. How to preprocess text classification datasets
# 2. How to create a simple word embedding layer that maps words to dense vectors

# %% [markdown]
# ## (Optional) Mount folder in Colab
#
# Uncomment the following cell to mount your gdrive if you are using the notebook in google colab:

# %%
# Use the following lines if you want to use Google Colab
# We presume you created a folder "i2dl" within your main drive folder, and put the exercise there.
# NOTE: terminate all other colab sessions that use GPU!
# NOTE 2: Make sure the correct exercise folder (e.g exercise_11) is given.

"""
from google.colab import drive
import os

gdrive_path='/content/gdrive/MyDrive/i2dl/exercise_11'

# This will mount your google drive under 'MyDrive'
drive.mount('/content/gdrive', force_remount=True)
# In order to access the files in this notebook we have to navigate to the correct folder
os.chdir(gdrive_path)
# Check manually if all files are present
print(sorted(os.listdir()))
"""

# %% [markdown]
# ### Set up PyTorch environment in colab
# - (OPTIONAL) Enable GPU via Runtime --> Change runtime type --> GPU
# - Uncomment the following cell if you are using the notebook in google colab:

# %%
# Optional: install correct libraries in google colab
# !python -m pip install torch==1.11.0+cu113 torchvision==0.12.0+cu113 -f https://download.pytorch.org/whl/torch_stable.html
# !python -m pip install tensorboard==2.8.0
# !python -m pip install pytorch-lightning==1.6.0
# Out:
# Looking in links: https://download.pytorch.org/whl/torch_stable.html
# Requirement already satisfied: torch==1.11.0+cu113 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (1.11.0+cu113)
# Requirement already satisfied: torchvision==0.12.0+cu113 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (0.12.0+cu113)
# Requirement already satisfied: typing-extensions in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from torch==1.11.0+cu113) (4.4.0)
# Requirement already satisfied: numpy in /home/samyeli/.local/lib/python3.10/site-packages (from torchvision==0.12.0+cu113) (1.23.4)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from torchvision==0.12.0+cu113) (9.2.0)
# Requirement already satisfied: requests in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from torchvision==0.12.0+cu113) (2.28.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from requests->torchvision==0.12.0+cu113) (2022.9.24)
# Requirement already satisfied: idna<4,>=2.5 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from requests->torchvision==0.12.0+cu113) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from requests->torchvision==0.12.0+cu113) (2.1.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from requests->torchvision==0.12.0+cu113) (1.26.13)
# Requirement already satisfied: tensorboard==2.8.0 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (2.8.0)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from tensorboard==2.8.0) (2.15.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from tensorboard==2.8.0) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from tensorboard==2.8.0) (0.4.6)
# Requirement already satisfied: setuptools>=41.0.0 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from tensorboard==2.8.0) (63.4.1)
# Requirement already satisfied: markdown>=2.6.8 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from tensorboard==2.8.0) (3.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from tensorboard==2.8.0) (2.28.1)
# Requirement already satisfied: protobuf>=3.6.0 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from tensorboard==2.8.0) (3.19.6)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from tensorboard==2.8.0) (0.6.1)
# Requirement already satisfied: wheel>=0.26 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from tensorboard==2.8.0) (0.37.1)
# Requirement already satisfied: absl-py>=0.4 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from tensorboard==2.8.0) (1.3.0)
# Requirement already satisfied: grpcio>=1.24.3 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from tensorboard==2.8.0) (1.51.1)
# Requirement already satisfied: numpy>=1.12.0 in /home/samyeli/.local/lib/python3.10/site-packages (from tensorboard==2.8.0) (1.23.4)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from tensorboard==2.8.0) (2.2.2)
# Requirement already satisfied: six>=1.9.0 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard==2.8.0) (1.16.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard==2.8.0) (0.2.8)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard==2.8.0) (4.9)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard==2.8.0) (5.2.0)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.8.0) (1.3.1)
# Requirement already satisfied: certifi>=2017.4.17 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard==2.8.0) (2022.9.24)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard==2.8.0) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard==2.8.0) (3.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorboard==2.8.0) (2.1.1)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from werkzeug>=0.11.15->tensorboard==2.8.0) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard==2.8.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard==2.8.0) (3.2.2)
# Requirement already satisfied: pytorch-lightning==1.6.0 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (1.6.0)
# Requirement already satisfied: torch>=1.8.* in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from pytorch-lightning==1.6.0) (1.11.0+cu113)
# Requirement already satisfied: numpy>=1.17.2 in /home/samyeli/.local/lib/python3.10/site-packages (from pytorch-lightning==1.6.0) (1.23.4)
# Requirement already satisfied: torchmetrics>=0.4.1 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from pytorch-lightning==1.6.0) (0.11.0)
# Requirement already satisfied: PyYAML>=5.4 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from pytorch-lightning==1.6.0) (6.0)
# Requirement already satisfied: typing-extensions>=4.0.0 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from pytorch-lightning==1.6.0) (4.4.0)
# Requirement already satisfied: tensorboard>=2.2.0 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from pytorch-lightning==1.6.0) (2.8.0)
# Requirement already satisfied: tqdm>=4.41.0 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from pytorch-lightning==1.6.0) (4.63.1)
# Requirement already satisfied: pyDeprecate<0.4.0,>=0.3.1 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from pytorch-lightning==1.6.0) (0.3.2)
# Requirement already satisfied: fsspec[http]!=2021.06.0,>=2021.05.0 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from pytorch-lightning==1.6.0) (2022.11.0)
# Requirement already satisfied: packaging>=17.0 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from pytorch-lightning==1.6.0) (21.3)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0) (3.8.3)
# Requirement already satisfied: requests in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0) (2.28.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from packaging>=17.0->pytorch-lightning==1.6.0) (3.0.9)
# Requirement already satisfied: protobuf>=3.6.0 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.0) (3.19.6)
# Requirement already satisfied: markdown>=2.6.8 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.0) (3.4.1)
# Requirement already satisfied: setuptools>=41.0.0 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.0) (63.4.1)
# Requirement already satisfied: wheel>=0.26 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.0) (0.37.1)
# Requirement already satisfied: werkzeug>=0.11.15 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.0) (2.2.2)
# Requirement already satisfied: tensorboard-data-server<0.7.0,>=0.6.0 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.0) (0.6.1)
# Requirement already satisfied: absl-py>=0.4 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.0) (1.3.0)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.0) (1.8.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.0) (0.4.6)
# Requirement already satisfied: grpcio>=1.24.3 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.0) (1.51.1)
# Requirement already satisfied: google-auth<3,>=1.6.3 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from tensorboard>=2.2.0->pytorch-lightning==1.6.0) (2.15.0)
# Requirement already satisfied: yarl<2.0,>=1.0 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0) (1.8.2)
# Requirement already satisfied: aiosignal>=1.1.2 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0) (1.3.1)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0) (4.0.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0) (1.3.3)
# Requirement already satisfied: charset-normalizer<3.0,>=2.0 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0) (2.1.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0) (6.0.3)
# Requirement already satisfied: attrs>=17.3.0 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0) (22.1.0)
# Requirement already satisfied: rsa<5,>=3.1.4 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.6.0) (4.9)
# Requirement already satisfied: six>=1.9.0 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.6.0) (1.16.0)
# Requirement already satisfied: cachetools<6.0,>=2.0.0 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.6.0) (5.2.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.6.0) (0.2.8)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning==1.6.0) (1.3.1)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0) (1.26.13)
# Requirement already satisfied: idna<4,>=2.5 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from requests->fsspec[http]!=2021.06.0,>=2021.05.0->pytorch-lightning==1.6.0) (2022.9.24)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from werkzeug>=0.11.15->tensorboard>=2.2.0->pytorch-lightning==1.6.0) (2.1.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from pyasn1-modules>=0.2.1->google-auth<3,>=1.6.3->tensorboard>=2.2.0->pytorch-lightning==1.6.0) (0.4.8)
# Requirement already satisfied: oauthlib>=3.0.0 in /home/samyeli/anaconda3/envs/i2dl/lib/python3.10/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard>=2.2.0->pytorch-lightning==1.6.0) (3.2.2)

# %% [markdown]
# # 0. Setup
#
# As usual, we first import some packages to setup this notebook.

# %%
import os
import torch
import matplotlib.pyplot as plt
from torch.utils.data import DataLoader

from exercise_code.rnn.sentiment_dataset import (
    create_dummy_data,
    download_data
)

# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading external modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # 1. Preprocessing a Text Classification Dataset
#
# As a starting point, let's load a dummy text classification dataset and have a sense of how it looks. We take these samples from the IMDb movie review dataset, which includes movie reviews and labels that show whether they are negative (0) or positive (1). You will investigate this task further in the second notebook.
#
# In this section, our goal is to create a text processing dataset. You are not required to write any code in this section. However, the concept introduced here is very important for working on NLP datasets in the future as well as in the rest of this exercise.
# Take your time to understand the procedure here.
#
# First, let us download the data and take a look at some data samples.

# %%
i2dl_exercises_path = os.path.dirname(os.path.abspath(os.getcwd()))
data_root = os.path.join(i2dl_exercises_path, "datasets", "SentimentData")
path = download_data(data_root)
data = create_dummy_data(path)
for text, label in data:
    print('Text: {}'.format(text))
    print('Label: {}'.format(label))
    print()
# Out:
# Downloading https://i2dl.vc.in.tum.de/static/data/SentimentData.zip to /mnt/d/samyeli/Desktop/M/WS22/IN2346/Exercises/i2dl/datasets/SentimentData/SentimentData.zip
# 3776512it [00:01, 2448299.53it/s]
# Text: This is the definitive movie version of Hamlet. Branagh cuts nothing, but there are no wasted moments.
# Label: 1
#
# Text: I don't know why I like this movie so well, but I never get tired of watching it.
# Label: 1
#
# Text: Smallville episode Justice is the best episode of Smallville ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! It's my favorite episode of Smallville! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! ! !
# Label: 1
#
# Text: This movie is terrible but it has some good effects.
# Label: 0
#
# Text: A rating of "1" does not begin to express how dull, depressing and relentlessly bad this movie is.
# Label: 0
#
# Text: Long, boring, blasphemous. Never have I been so glad to see ending credits roll.
# Label: 0

# %% [markdown]
# ## 1.1 Tokenizing Data
#
# As seen above, we loaded 3 positive and 3 negative reviews. Since the basic semantic unit of text is a word, the first thing we need to do is **tokenizing** the dataset, which means converting each review to a list of words.

# %%
import re

# use regular expression to split the sentence
# check https://docs.python.org/3/library/re.html for more information
def tokenize(text):
    return [s.lower() for s in re.split(r'\W+', text) if len(s) > 0]

tokenized_data = []
for text, label in data:
    tokenized_data.append((tokenize(text), label))
    print(tokenized_data[-1], '\n')
# Out:
# (['this', 'is', 'the', 'definitive', 'movie', 'version', 'of', 'hamlet', 'branagh', 'cuts', 'nothing', 'but', 'there', 'are', 'no', 'wasted', 'moments'], 1)
#
# (['i', 'don', 't', 'know', 'why', 'i', 'like', 'this', 'movie', 'so', 'well', 'but', 'i', 'never', 'get', 'tired', 'of', 'watching', 'it'], 1)
#
# (['smallville', 'episode', 'justice', 'is', 'the', 'best', 'episode', 'of', 'smallville', 'it', 's', 'my', 'favorite', 'episode', 'of', 'smallville'], 1)
#
# (['this', 'movie', 'is', 'terrible', 'but', 'it', 'has', 'some', 'good', 'effects'], 0)
#
# (['a', 'rating', 'of', '1', 'does', 'not', 'begin', 'to', 'express', 'how', 'dull', 'depressing', 'and', 'relentlessly', 'bad', 'this', 'movie', 'is'], 0)
#
# (['long', 'boring', 'blasphemous', 'never', 'have', 'i', 'been', 'so', 'glad', 'to', 'see', 'ending', 'credits', 'roll'], 0)

# %% [markdown]
# ## 1.2 Creating a Vocabulary
#
# We have converted the dataset into pairs of token lists and corresponding labels. But strings have varying lengths, which is hard to handle. It would be nice to represent words with numbers. So, we need to create a <b>vocabulary</b>, which is a dictionary that maps each word to an integer id.
#
# In large datasets, there are too many words, and most of them don't occur very frequently. One common approach we use to tackle this problem is to pick the most common N words from the dataset. Therefore, we restrict the number of words.
#
# First, let's compute the word frequencies in our dummy dataset. To compute frequencies, we use the [Counter](https://docs.python.org/3/library/collections.html#collections.Counter) data structure.

# %%
from collections import Counter

freqs = Counter()
for tokens, _ in tokenized_data:
    freqs.update(tokens)

freqs
# Out:
# Counter({'this': 4,
#          'is': 4,
#          'the': 2,
#          'definitive': 1,
#          'movie': 4,
#          'version': 1,
#          'of': 5,
#          'hamlet': 1,
#          'branagh': 1,
#          'cuts': 1,
#          'nothing': 1,
#          'but': 3,
#          'there': 1,
#          'are': 1,
#          'no': 1,
#          'wasted': 1,
#          'moments': 1,
#          'i': 4,
#          'don': 1,
#          't': 1,
#          'know': 1,
#          'why': 1,
#          'like': 1,
#          'so': 2,
#          'well': 1,
#          'never': 2,
#          'get': 1,
#          'tired': 1,
#          'watching': 1,
#          'it': 3,
#          'smallville': 3,
#          'episode': 3,
#          'justice': 1,
#          'best': 1,
#          's': 1,
#          'my': 1,
#          'favorite': 1,
#          'terrible': 1,
#          'has': 1,
#          'some': 1,
#          'good': 1,
#          'effects': 1,
#          'a': 1,
#          'rating': 1,
#          '1': 1,
#          'does': 1,
#          'not': 1,
#          'begin': 1,
#          'to': 2,
#          'express': 1,
#          'how': 1,
#          'dull': 1,
#          'depressing': 1,
#          'and': 1,
#          'relentlessly': 1,
#          'bad': 1,
#          'long': 1,
#          'boring': 1,
#          'blasphemous': 1,
#          'have': 1,
#          'been': 1,
#          'glad': 1,
#          'see': 1,
#          'ending': 1,
#          'credits': 1,
#          'roll': 1})

# %% [markdown]
# To create the dictionary, let's select the most common 20 words to create a vocabulary. In addition to the words that appear in our data, we need to have two special words:
#
# - `<eos>` End of sequence symbol used for padding
# - `<unk>` Words unknown in our vocabulary

# %%
vocab = {'<eos>': 0, '<unk>': 1}
for token, freq in freqs.most_common(20):
    vocab[token] = len(vocab)
vocab
# Out:
# {'<eos>': 0,
#  '<unk>': 1,
#  'of': 2,
#  'this': 3,
#  'is': 4,
#  'movie': 5,
#  'i': 6,
#  'but': 7,
#  'it': 8,
#  'smallville': 9,
#  'episode': 10,
#  'the': 11,
#  'so': 12,
#  'never': 13,
#  'to': 14,
#  'definitive': 15,
#  'version': 16,
#  'hamlet': 17,
#  'branagh': 18,
#  'cuts': 19,
#  'nothing': 20,
#  'there': 21}

# %% [markdown]
# ## 1.3 Creating the Dataset
#
# Putting it all together, we can now create a dataset class. First, let's create index-label pairs:

# %%
indexed_data = []
for tokens, label in tokenized_data:
    indices = [vocab.get(token, vocab['<unk>']) for token in tokens]    
    # the token that is not in vocab get assigned <unk>
    indexed_data.append((indices, label))
    

for indices, label in indexed_data:
    print(indices, ' -> ', label)
    print()
# Out:
# [3, 4, 11, 15, 5, 16, 2, 17, 18, 19, 20, 7, 21, 1, 1, 1, 1]  ->  1
#
# [6, 1, 1, 1, 1, 6, 1, 3, 5, 12, 1, 7, 6, 13, 1, 1, 2, 1, 8]  ->  1
#
# [9, 10, 1, 4, 11, 1, 10, 2, 9, 8, 1, 1, 1, 10, 2, 9]  ->  1
#
# [3, 5, 4, 1, 7, 8, 1, 1, 1, 1]  ->  0
#
# [1, 1, 2, 1, 1, 1, 1, 14, 1, 1, 1, 1, 1, 1, 1, 3, 5, 4]  ->  0
#
# [1, 1, 1, 13, 1, 6, 1, 12, 1, 14, 1, 1, 1, 1]  ->  0

# %% [markdown]
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>We now use the PyTorch dataset class we provided in <code>exercise_code/rnn/sentiment_dataset.py</code> file. Please also take a look at the code.</p>
#  </div>
#
#
#
# Dataset class also reverse sorts the sequences with respect to the lengths. Thanks to this sorting, we can reduce the total number of padded elements, which means that we have less computations for padded values.

# %%
from exercise_code.rnn.sentiment_dataset import SentimentDataset

combined_data = [
    (raw_text, tokens, indices, label)
    for (raw_text, label), (tokens, _), (indices, _)
    in zip(data, tokenized_data, indexed_data)
]

dataset = SentimentDataset(combined_data)

for elem in dataset:
    print(elem)
    print()
# Out:
# {'data': tensor([ 6,  1,  1,  1,  1,  6,  1,  3,  5, 12,  1,  7,  6, 13,  1,  1,  2,  1,
#          8]), 'label': tensor(1.)}
#
# {'data': tensor([ 1,  1,  2,  1,  1,  1,  1, 14,  1,  1,  1,  1,  1,  1,  1,  3,  5,  4]), 'label': tensor(0.)}
#
# {'data': tensor([ 3,  4, 11, 15,  5, 16,  2, 17, 18, 19, 20,  7, 21,  1,  1,  1,  1]), 'label': tensor(1.)}
#
# {'data': tensor([ 9, 10,  1,  4, 11,  1, 10,  2,  9,  8,  1,  1,  1, 10,  2,  9]), 'label': tensor(1.)}
#
# {'data': tensor([ 1,  1,  1, 13,  1,  6,  1, 12,  1, 14,  1,  1,  1,  1]), 'label': tensor(0.)}
#
# {'data': tensor([3, 5, 4, 1, 7, 8, 1, 1, 1, 1]), 'label': tensor(0.)}

# %% [markdown]
# ## 1.4 Minibatching
# Note that in the dataset we created, not all sequences have the same length. Therefore, we cannot minibatch the data trivially. This means we cannot use a `DataLoader` class easily.
#
# <b>If you uncomment the following cell and run it, you will very likely get an error!</b>

# %%
# loader = DataLoader(dataset, batch_size=3)

# for batch in loader:
#     print(batch)

# %% [markdown]
# <div class="alert alert-success">
#     <h3>Task: Check Code</h3>
#     <p>To solve the problem, we need to pad the sequences with <code> < eos > </code> tokens that we indexed as zero. To integrate this approach into the Pytorch <a href="https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader" target="_blank">Dataloader</a> class, we will make use of the <code>collate_fn</code> argument. For more details, check out the <code>collate</code> function in <code>exercise_code/rnn/sentiment_dataset</code>. </p>
#     <p> In addition, we use the <a href="https://pytorch.org/docs/stable/generated/torch.nn.utils.rnn.pad_sequence.html" target="_blank">pad_sequence</a> that pads shorter sequences with 0. </p>
#  </div>

# %%
from torch.nn.utils.rnn import pad_sequence

def collate(batch):
    assert isinstance(batch, list)
    data = pad_sequence([b['data'] for b in batch])
    lengths = torch.tensor([len(b['data']) for b in batch])
    label = torch.stack([b['label'] for b in batch])
    return {
        'data': data,
        'label': label,
        'lengths': lengths
    }

loader = DataLoader(dataset, batch_size=3, collate_fn=collate)
for batch in loader:
    print('Data: \n', batch['data'])
    print('\nLabels: \n', batch['label'])
    print('\nSequence Lengths: \n', batch['lengths'])
    print('\n')
# Out:
# Data:
#  tensor([[ 6,  1,  3],
#         [ 1,  1,  4],
#         [ 1,  2, 11],
#         [ 1,  1, 15],
#         [ 1,  1,  5],
#         [ 6,  1, 16],
#         [ 1,  1,  2],
#         [ 3, 14, 17],
#         [ 5,  1, 18],
#         [12,  1, 19],
#         [ 1,  1, 20],
#         [ 7,  1,  7],
#         [ 6,  1, 21],
#         [13,  1,  1],
#         [ 1,  1,  1],
#         [ 1,  3,  1],
#         [ 2,  5,  1],
#         [ 1,  4,  0],
#         [ 8,  0,  0]])
#
# Labels:
#  tensor([1., 0., 1.])
#
# Sequence Lengths:
#  tensor([19, 18, 17])
#
#
# Data:
#  tensor([[ 9,  1,  3],
#         [10,  1,  5],
#         [ 1,  1,  4],
#         [ 4, 13,  1],
#         [11,  1,  7],
#         [ 1,  6,  8],
#         [10,  1,  1],
#         [ 2, 12,  1],
#         [ 9,  1,  1],
#         [ 8, 14,  1],
#         [ 1,  1,  0],
#         [ 1,  1,  0],
#         [ 1,  1,  0],
#         [10,  1,  0],
#         [ 2,  0,  0],
#         [ 9,  0,  0]])
#
# Labels:
#  tensor([1., 0., 0.])
#
# Sequence Lengths:
#  tensor([16, 14, 10])

# %% [markdown]
# We can see that these two batches have different length, this is how the reverse sort mentioned in `1.3 Creating the Dataset` benefits for less memory and less computation.

# %% [markdown]
# # 2. Embeddings
#
# In the previous section, we explored how to convert text into a sequence of integers. In this form, sequences are still not ready to be inputs of RNNs you implemented in the optional notebook.
#
# An integer representation is usually a one-hot encoding, while not the same since they are not equally weighted given only an integer.
#
# Moreover, it fails to express the semantic relations between words and the order of the words has no meaning. We would like a better representation to keep the semantic meaning of the word. For example, as shown in the following picture, the difference between man and woman and the difference between king and queen should be close, since the difference is only the gender. If we use a vector for each word, the above relation can be expressed as $vec(\text{women})-vec(\text{man}) \approx vec(\text{queen}) - vec(\text{king})$. Usually we call such vector representations as embeddings.
#
# <img src='https://developers.google.com/machine-learning/crash-course/images/linear-relationships.svg' width=80% height=80%/>
#
# While one can use pre-trained embedding vectors such as [word2vec](https://arxiv.org/abs/1301.3781) or [GLoVe](https://nlp.stanford.edu/projects/glove/), in this exercise we use randomly initialized embedding vectors that will be trained from scratch together with our networks. As we train our model, it will learn the semantic relations between words.

# %% [markdown]
# <div class="alert alert-info">
#
# <h3> Task: Implement Embedding</h3>
#  <p>In this part, you will implement a simple embedding layer. Embedding is a simple lookup table that stores a dense vector to represent each word in the vocabulary.</p>
#
#  <p>Your task is to implement the <code>Embedding</code> class in <code>exercise_code.rnn.rnn_nn</code> file. Once you are done, run the below cell to test your implementation. Note that we ensure eos embeddings to be zero by using the <code>padding_idx</code> argument.
#
#  </div>

# %%
import torch.nn as nn

from exercise_code.rnn.rnn_nn import Embedding
from exercise_code.rnn.tests import embedding_output_test


i2dl_embedding = Embedding(len(vocab), 16, padding_idx=0)
pytorch_embedding = nn.Embedding(len(vocab), 16, padding_idx=0)

loader = DataLoader(dataset, batch_size=len(dataset), collate_fn=collate)
for batch in loader:
    x = batch['data']

embedding_output_test(i2dl_embedding, pytorch_embedding, x)
# Out:
# Difference between outputs: 0.0
# Test passed :)!
# True

# %% [markdown]
# # 3. Conclusion
#
# In this notebook, you learned how to prepare text data and how to create an embedding layer. In the next notebook, you will combine your Embedding and RNN implementations to create a sentiment analysis network!
